# %%
import numpy as np
import json
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS

# %%
items2018 = 52706
pages = 1034   #there are 51 runners per page here

# %%
headers ={'Token':'6112c32703f442f0'}
url = 'https://results.nyrr.org/api/runners/finishers-filter'
body = '{"eventCode":"M2018","runnerId":null,"searchString":null,"countryCode":null,"stateProvince":null,"city":null,"teamName":null,"teamCode":null,"gender":null,"ageFrom":null,"ageTo":null,"overallPlaceFrom":null,"overallPlaceTo":null,"paceFrom":null,"paceTo":null,"overallTimeFrom":null,"overallTimeTo":null,"gunTimeFrom":null,"gunTimeTo":null,"ageGradedTimeFrom":null,"ageGradedTimeTo":null,"ageGradedPlaceFrom":null,"ageGradedPlaceTo":null,"ageGradedPerformanceFrom":null,"ageGradedPerformanceTo":null,"handicap":null,"sortColumn":"overallTime","sortDescending":false,"pageIndex":1,"pageSize":50}'

# %%
body_dict = json.loads(body)

# %%
body_dict
# Out:
# {'eventCode': 'M2018',
#  'runnerId': None,
#  'searchString': None,
#  'countryCode': None,
#  'stateProvince': None,
#  'city': None,
#  'teamName': None,
#  'teamCode': None,
#  'gender': None,
#  'ageFrom': None,
#  'ageTo': None,
#  'overallPlaceFrom': None,
#  'overallPlaceTo': None,
#  'paceFrom': None,
#  'paceTo': None,
#  'overallTimeFrom': None,
#  'overallTimeTo': None,
#  'gunTimeFrom': None,
#  'gunTimeTo': None,
#  'ageGradedTimeFrom': None,
#  'ageGradedTimeTo': None,
#  'ageGradedPlaceFrom': None,
#  'ageGradedPlaceTo': None,
#  'ageGradedPerformanceFrom': None,
#  'ageGradedPerformanceTo': None,
#  'handicap': None,
#  'sortColumn': 'overallTime',
#  'sortDescending': False,
#  'pageIndex': 1,
#  'pageSize': 50}

# %%
result = requests.post(url, json = body_dict, headers = headers)
result #Response 200 means ok
# Out:
# <Response [200]>

# %%
result_set = result.json()['response']['items']
#result.json() wil show first 50, have to nest down to response >items

# %%
pd.DataFrame(result_set)
# Out:
#     runnerId   firstName            lastName   bib  age            birthdate  \
# 0   22025442      Lelisa              Desisa     3   28  1990-01-14T00:00:00
# 1   22074276       Shura              Kitata     2   22  1996-06-09T00:00:00
# 2   22038636    Geoffrey            Kamworor     1   25  1992-11-22T00:00:00
# 3   22074280     Tamirat                Tola     4   27  1991-08-11T00:00:00
# 4   22074281      Daniel             Wanjiru     5   26  1992-05-25T00:00:00
# 5   22048416       Jared                Ward    15   30  1988-09-09T00:00:00
# 6   22043170       Scott              Fauble    18   26  1991-11-05T00:00:00
# 7   22074279      Festus               Talam     6   24  1994-10-20T00:00:00
# 8   22030005    Shadrack              Biwott    11   33  1985-02-19T00:00:00
# 9   22031893       Chris             Derrick    19   28  1990-10-17T00:00:00
# 10  22027349   Juan Luis             Barrios     9   35  1983-06-24T00:00:00
# 11  22042654     Tadesse            Yae Dabi   443   29  1988-11-21T00:00:00
# 12  22028576         Tim             Ritchie    12   31  1987-08-07T00:00:00
# 13  22027895        Ryan                Vail    16   32  1986-03-19T00:00:00
# 14  22029483       Jonny              Mellor    21   31  1986-12-27T00:00:00
# 15  22022951     Harbert               Okuti    28   33  1985-10-25T00:00:00
# 16  22074278       Scott               Smith    17   32  1986-07-13T00:00:00
# 17  22027963     Bernard               Lagat    10   43  1974-12-12T00:00:00
# 18  22031740       Girma        Bekele Gebre   440   25  1992-12-29T00:00:00
# 19  22034253     Birhanu          Dare Kemal    27   32  1986-07-19T00:00:00
# 20  22068851      Mizael             Carrera    29   27  1991-08-25T00:00:00
# 21  22034446     Suleman         Abrar Shifa   444   25  1993-06-07T00:00:00
# 22  22031644      Diriba       Degefa Yigezu   446   30  1987-11-21T00:00:00
# 23  22050037    Temesgen  Habtemariam Bekele   448   28  1990-10-21T00:00:00
# 24  22066339      Andrew              Davies    23   39  1979-10-30T00:00:00
# 25  22026918        Mary             Keitany   102   36  1982-01-18T00:00:00
# 26  22074275     Florent              Caelen    20   29  1989-03-01T00:00:00
# 27  22054028      Jeremy              Bennie  1172   24  1993-11-15T00:00:00
# 28  22042138        Matt           Gillespie   457   28  1990-11-04T00:00:00
# 29  22051050        Luis              Rivero   445   31  1987-02-23T00:00:00
# 30  22058820     Derrick               Hamel  1188   35  1983-06-08T00:00:00
# 31  22059446      Vivian           Cheruiyot   104   35  1983-09-11T00:00:00
# 32  22052744  Aliaksandr           Leuchanka  1223   27  1991-05-27T00:00:00
# 33  22026917     Shalane            Flanagan   101   37  1981-07-08T00:00:00
# 34  22042506        Alex              Monroe    22   26  1992-03-30T00:00:00
# 35  22030371    Nicholas              Hilton    24   29  1989-04-28T00:00:00
# 36  22030354       Molly              Huddle   106   34  1984-08-31T00:00:00
# 37  22038944      Daniel                Glaz   453   35  1983-04-27T00:00:00
# 38  22074272       Rahma                Tusa   110   25  1993-09-14T00:00:00
# 39  22066642        Nick           McCormick   455   37  1981-09-11T00:00:00
# 40  22067484       Felix              Plinke  1147   29  1989-07-18T00:00:00
# 41  22032962       James               Kelly   544   35  1983-08-29T00:00:00
# 42  22027979     Desiree              Linden   105   35  1983-07-26T00:00:00
# 43  22043254       David             Kilgore   554   26  1991-11-21T00:00:00
# 44  22059397        Jack            St Marie   449   26  1992-06-25T00:00:00
# 45  22050576     Matthew              Beamer  1153   31  1987-08-18T00:00:00
# 46  22033719       Allie             Kieffer   107   31  1987-09-16T00:00:00
# 47  22072404    Cristian          Marianelli  1148   41  1976-12-23T00:00:00
# 48  22051274       Peter            Lighting  1155   37  1980-12-07T00:00:00
# 49  22051174        Sean         Fitzpatrick  1216   28  1989-11-13T00:00:00
#
#    gender                city countryCode stateProvince iaaf  overallPlace  \
# 0       M         Addis Ababa         ETH          None  ETH             1
# 1       M         Addis Ababa         ETH          None  ETH             2
# 2       M  Kapchorwa District         KEN          None  KEN             3
# 3       M         Addis Ababa         ETH          None  ETH             4
# 4       M                Embu         KEN          None  KEN             5
# 5       M            Mapleton         USA            UT  USA             6
# 6       M           Flagstaff         USA            AZ  USA             7
# 7       M                Iten         KEN          None  KEN             8
# 8       M              Folsom         USA            CA  USA             9
# 9       M            Portland         USA            OR  USA            10
# 10      M         Mexico City         MEX          None  MEX            11
# 11      M            New York         USA            NY  ETH            12
# 12      M         Northampton         USA            MA  USA            13
# 13      M            Portland         USA            OR  USA            14
# 14      M           Liverpool         GBR          None  GBR            15
# 15      M          High Falls         USA            NY  UGA            16
# 16      M           Flagstaff         USA            AZ  USA            17
# 17      M              Tucson         USA            AZ  USA            18
# 18      M            New York         USA            NY  ETH            19
# 19      M            New York         USA            NY  ETH            20
# 20      M         Albuquerque         USA            NM  PUR            21
# 21      M               Bronx         USA            NY  ETH            22
# 22      M            New York         USA            NY  ETH            23
# 23      M            New York         USA            NY  ETH            24
# 24      M             Newtown         GBR          None  GBR            25
# 25      F                Iten         KEN          None  KEN            26
# 26      M            Soumagne         BEL          None  BEL            27
# 27      M            New York         USA            NY  USA            28
# 28      M          Somerville         USA            MA  GBR            29
# 29      M          San Marcos         GTM          None  GUA            30
# 30      M           Newmarket         USA            NH  USA            31
# 31      F             Eldoret         KEN          None  KEN            32
# 32      M                 Lee         USA            NH  USA            33
# 33      F            Portland         USA            OR  USA            34
# 34      M            Longmont         USA            CO  USA            35
# 35      M           Flagstaff         USA            AZ  USA            36
# 36      F          Providence         USA            RI  USA            37
# 37      M             Chicago         USA            IL  USA            38
# 38      F         Addis Ababa         ETH          None  ETH            39
# 39      M               Fence         GBR          None  GBR            40
# 40      M            Wehrheim         DEU          None  GER            41
# 41      M            New York         USA            NY  USA            42
# 42      F          Charlevoix         USA            MI  USA            43
# 43      M            New York         USA            NY  USA            44
# 44      M            La Jolla         USA            CA  USA            45
# 45      M             Chicago         USA            IL  USA            46
# 46      F          West Islip         USA            NY  USA            47
# 47      M                Lama         ITA          None  ITA            48
# 48      M              London         GBR          None  USA            49
# 49      M              London         GBR          None  GBR            50
#
#    overallTime   pace  genderPlace ageGradeTime  ageGradePlace  \
# 0      2:05:59  04:49            1        05:59              1
# 1      2:06:01  04:49            2        06:01              2
# 2      2:06:26  04:50            3        06:26              3
# 3      2:08:30  04:55            4        08:30              4
# 4      2:10:21  04:59            5        10:21              5
# 5      2:12:24  05:03            6        12:24              7
# 6      2:12:28  05:04            7        12:28              8
# 7      2:12:40  05:04            8        12:40              9
# 8      2:12:52  05:05            9        12:43             10
# 9      2:13:08  05:05           10        13:08             11
# 10     2:13:55  05:07           11        13:15             12
# 11     2:13:57  05:07           12        13:57             13
# 12     2:15:22  05:10           13        15:22             14
# 13     2:15:31  05:11           14        15:29             15
# 14     2:16:09  05:12           15        16:09             16
# 15     2:16:51  05:14           16        16:42             17
# 16     2:17:12  05:14           17        17:11             18
# 17     2:17:20  05:15           18        10:33              6
# 18     2:18:18  05:17           19        18:18             21
# 19     2:18:20  05:17           20        18:19             22
# 20     2:19:29  05:20           21        19:29             23
# 21     2:19:45  05:20           22        19:45             24
# 22     2:20:01  05:21           23        20:01             26
# 23     2:20:16  05:21           24        20:16             28
# 24     2:20:23  05:22           25        17:21             19
# 25     2:22:48  05:27            1        21:17              1
# 26     2:22:53  05:27           26        22:53             31
# 27     2:23:16  05:28           27        23:16             33
# 28     2:25:05  05:32           28        25:05             44
# 29     2:25:25  05:33           29        25:25             46
# 30     2:25:43  05:34           30        24:59             43
# 31     2:26:02  05:35            2        24:57              3
# 32     2:26:11  05:35           31        26:11             53
# 33     2:26:22  05:35            3        24:14              2
# 34     2:26:28  05:36           32        26:28             57
# 35     2:26:31  05:36           33        26:31             58
# 36     2:26:44  05:36            4        26:03              6
# 37     2:26:45  05:36           34        26:01             50
# 38     2:27:13  05:37            5        27:13              9
# 39     2:27:35  05:38           35        25:50             48
# 40     2:27:43  05:39           36        27:43             68
# 41     2:27:49  05:39           37        27:05             62
# 42     2:27:51  05:39            6        26:45              8
# 43     2:28:01  05:39           38        28:01             70
# 44     2:28:05  05:39           39        28:05             71
# 45     2:28:08  05:39           40        28:08             73
# 46     2:28:12  05:40            7        28:10             10
# 47     2:28:35  05:40           41        23:30             34
# 48     2:28:41  05:41           42        26:56             60
# 49     2:28:43  05:41           43        28:43             81
#
#     ageGradePercent  racesCount
# 0             97.60           5
# 1             97.57           2
# 2             97.25           4
# 3             95.69           2
# 4             94.33           1
# 5             92.87           5
# 6             92.82           6
# 7             92.69           1
# 8             92.64           6
# 9             92.36           4
# 10            92.28           9
# 11            91.79          36
# 12            90.84           3
# 13            90.75           3
# 14            90.31           3
# 15            89.95          60
# 16            89.63           2
# 17            94.19           9
# 18            88.91          31
# 19            88.90          50
# 20            88.15           1
# 21            87.98          61
# 22            87.82          52
# 23            87.66          21
# 24            89.52           2
# 25            95.86          11
# 26            86.06           1
# 27            85.83           2
# 28            84.75          15
# 29            84.55           2
# 30            84.81           1
# 31            93.43           1
# 32            84.11           1
# 33            93.90           5
# 34            83.95           3
# 35            83.92           1
# 36            92.72          13
# 37            84.20           3
# 38            91.99           1
# 39            84.31           1
# 40            83.24           1
# 41            83.60          56
# 42            92.28          22
# 43            83.07          11
# 44            83.03           1
# 45            83.00           4
# 46            91.40          17
# 47            85.68           1
# 48            83.68           1
# 49            82.68           1

# %%
df = pd.DataFrame(result_set)

# %%
df

# %%
#for loop to get each set of results per page of url
df = pd.DataFrame()
for index in range (1, 1035): #or can do (pages+1 as end number)
    #print(index)
    body_dict['pageIndex']=index
    result = requests.post(url, json = body_dict, headers = headers)
    result_set = result.json()['response']['items']
    df = df.append(pd.DataFrame(result_set))
    print(df.shape) #or run tail here

# %%
print(df.tail()) #this is stopping at runner place #10,000

# %%
print(body_dict)

# %%
df = df.reset_index(drop=True)

# %%
df.tail()

# %%
#export to csv to save each year results - only have first 10k places
df.to_csv('../data/nyc2018.csv')
